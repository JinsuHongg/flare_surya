# %%
import zarr
import xarray as xr
import pandas as pd

# %%
# data = zarr.open("./xrs_24hour_slices_g15_g16_merged.zarr", mode="r")
# print(list(data.keys()))

# %%
ds = xr.open_dataset("./xrs_24hour_slices_g15_g16_merged.zarr", chunks="auto", engine="zarr")

# %%
ds["timestep"].values
# Out:
# array(['2010-04-08T00:00:00.000000000', '2010-04-08T01:00:00.000000000',
#        '2010-04-08T02:00:00.000000000', ...,
#        '2025-04-05T22:00:00.000000000', '2025-04-05T23:00:00.000000000',
#        '2025-04-06T00:00:00.000000000'], dtype='datetime64[ns]')

# %%
t = pd.to_datetime(ds["timestep"].values)

# %%
t
# Out:
# DatetimeIndex(['2010-04-08 00:00:00', '2010-04-08 01:00:00',
#                '2010-04-08 02:00:00', '2010-04-08 03:00:00',
#                '2010-04-08 04:00:00', '2010-04-08 05:00:00',
#                '2010-04-08 06:00:00', '2010-04-08 07:00:00',
#                '2010-04-08 08:00:00', '2010-04-08 09:00:00',
#                ...
#                '2025-04-05 15:00:00', '2025-04-05 16:00:00',
#                '2025-04-05 17:00:00', '2025-04-05 18:00:00',
#                '2025-04-05 19:00:00', '2025-04-05 20:00:00',
#                '2025-04-05 21:00:00', '2025-04-05 22:00:00',
#                '2025-04-05 23:00:00', '2025-04-06 00:00:00'],
#               dtype='datetime64[ns]', length=131402, freq=None)
